# %% [markdown]
# # NCSN: Noise Conditional Score Network
#
# Generative Modeling by Estimating Gradients of the Data Distribution, Song & Ermon, 2019. [[arXiv:1907.05600](https://arxiv.org/abs/1907.05600)]
#
# ## 1. Prepare Dataset
#
# Define the gaussian mixture distribution as the target distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import gmm

X, Y = gmm(100000, weights=[0.3, 0.7], mean=[-0.5, 1.0], std=[0.1, 0.2])

_ = plt.hist(X, bins=np.linspace(-5, 5, 200), label="data")

# %% [markdown]
# ## 2. Define Model
#
# Define MLP backbone and NCSN framework.

# %%
from flowmodels import NCSN, NCSNScheduler
from utils import Backbone

COND = False
aux = 1 if not COND else 2
scheduler = NCSNScheduler()
model = NCSN(Backbone(aux=aux), scheduler)
model
# Out:
# NCSN(
#   (score_estim): Backbone(
#     (net): Sequential(
#       (0): Linear(in_features=2, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=64, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )

# %%
import torch

# intermediate plots
t = scheduler.T - 1
alpha_bar = 1 - scheduler.var()

prior = torch.randn_like(X)
noised = model.noise(X, torch.full((len(X),), t, dtype=torch.long), prior=prior)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

# 1D hists
plt.hist(X, bins=np.linspace(-5, 5, 200), label="data")
plt.hist(noised, bins=np.linspace(-5, 5, 200), label="noised", alpha=0.7)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(alpha_bar, label="\\bar\\alpha")
plt.legend()

# %% [markdown]
# ## 3. Train NCSN
#
# Train the score model with the prepared dataset.

# %%
import torch
from tqdm.auto import tqdm

from utils import vis

# training configurations
LR = 0.001
TRAIN_STEPS = 1000
BATCH_SIZE = 2048

# train
model.train()
optim = torch.optim.Adam(model.parameters(), LR)

losses = []
with tqdm(range(TRAIN_STEPS)) as pbar:
    for i in pbar:
        indices = torch.randint(0, len(X), (BATCH_SIZE,))
        loss = model.loss(
            sample=X[indices],
            label=Y[indices] if COND else None,
        )
        # update
        optim.zero_grad()
        loss.backward()
        optim.step()

        # log
        loss = loss.detach().item()
        losses.append(loss)
        pbar.set_postfix_str(f"loss: {loss:.2f}")

plt.plot(losses)
vis(model, conditional=COND, steps=[None])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
