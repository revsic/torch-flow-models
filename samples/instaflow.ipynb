# %% [markdown]
# # InstaFlow
#
# One Step is Enough for High-Quality Diffusion-Based Text-to-Image Generation, Liu et al., 2023. [[arXiv:2309.06380](https://arxiv.org/abs/2309.06380)]
#
# ## 1. Prepare Dataset
#
# Define the gaussian mixture distribution as the target distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import gmm

X, Y = gmm(100000, weights=[0.3, 0.7], mean=[-0.5, 1.0], std=[0.1, 0.2])

_ = plt.hist(X, bins=np.linspace(-5, 5, 200), label="data")

# %% [markdown]
# ## 2. Define Score Model
#
# Define MLP backbone and score model first.

# %%
from flowmodels import DDPM, DDIMScheduler
from utils import Backbone

COND = False
aux = 1 if not COND else 2
model = DDPM(Backbone(aux=aux), DDIMScheduler())
model
# Out:
# DDPM(
#   (noise_estim): Backbone(
#     (net): Sequential(
#       (0): Linear(in_features=2, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=64, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## 3. Train Score Model
#
# Train the score model with the prepared dataset.

# %%
import torch
from tqdm.auto import tqdm

from utils import vis

# training configurations
LR = 0.001
TRAIN_STEPS = 1000
BATCH_SIZE = 2048

# train
model.train()
optim = torch.optim.Adam(model.parameters(), LR)

losses = []
with tqdm(range(TRAIN_STEPS)) as pbar:
    for i in pbar:
        indices = torch.randint(0, len(X), (BATCH_SIZE,))
        loss = model.loss(
            sample=X[indices],
            label=Y[indices] if COND else None,
        )
        # update
        optim.zero_grad()
        loss.backward()
        optim.step()

        # log
        loss = loss.detach().item()
        losses.append(loss)
        pbar.set_postfix_str(f"loss: {loss:.2f}")

plt.plot(losses)
vis(model, conditional=COND, steps=[None])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## 4. Distill to InstaFlow
#
# Distill the knowledge of the pretrained score model to InstaFlow

# %%
import copy

from flowmodels import InstaFlow

# define instaflow
instaflow = InstaFlow(copy.deepcopy(model.noise_estim))

# distillation
LR = 0.001
SAMPLE_STEPS = 100
TRAIN_STEPS = 1000
BATCH_SIZE = 2048

n = 10000
prior = torch.randn(n, X.shape[-1])
optim = torch.optim.Adam(instaflow.parameters(), LR)
losses, rctor = instaflow.distill_from_score(
    model,
    model.scheduler,
    optim,
    prior,
    TRAIN_STEPS,
    BATCH_SIZE,
    label=Y[torch.randperm(len(Y))[:n]] if COND else None,
    verbose=lambda r: tqdm(r, leave=False),
)
plt.plot(losses)
vis(instaflow, conditional=COND, steps=[100])
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ### Distillation
#
# Distill the model for single-step generation

# %%
# REFLOW
LR = 0.001
SAMPLE_STEPS = 100
TRAIN_STEPS = 100
BATCH_SIZE = 2048

n = 10000
prior = torch.randn(n, X.shape[-1])

optim = torch.optim.Adam(instaflow.parameters(), LR)
losses = instaflow.distillation(
    optim,
    prior,
    training_steps=TRAIN_STEPS,
    batch_size=BATCH_SIZE,
    sample=SAMPLE_STEPS,
    label=Y[torch.randperm(len(Y))[:n]] if COND else None,
    verbose=lambda x: tqdm(x, leave=False),
)

plt.plot(losses)
vis(instaflow, conditional=COND, steps=[1])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
